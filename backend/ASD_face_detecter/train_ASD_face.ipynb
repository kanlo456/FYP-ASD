# %%
from ultralytics import YOLO
import multiprocessing
from ultralytics import settings

if __name__ == '__main__':
    multiprocessing.freeze_support()
    settings.reset()
    settings.update({'weights_dir': 'backend\YOLO_Train\ASD_face_decter'})
    settings.update({'runs_dir':'backend\YOLO_Train\ASD_face_decter'})

# %%
# Load a model
# model = YOLO('models/yolov8n')
model = YOLO('models/ASD_Face_detecter_v1.pt')

# %%
results = model.train(data='datasets/ya ml/ASD_face.yaml', epochs=300, imgsz=640,batch=-1,save=True)

# %%
# Train the model
result = model.train(data='datasets/yaml/ASD_face.yaml', batch=1, epochs=300, imgsz=640, project = 'ASD_face_decter_Result',name='exp01')
metrics = model.val()

# %%
from ultralytics import YOLO
# model = YOLO('models/ASD_Face_detecter_v1.pt')
model = YOLO('models/ASD_Face_detecter_v2.pt')

metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.16  Python-3.11.9 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12288MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\kanlo\Documents\GitHub\FYP-ASD\backend\ASD_face_detecter\datasets\ASD_face_data\labels\val.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/7 [00:00<?, ?it/s]c:\Users\kanlo\anaconda3\envs\ASD_detection\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# ...

# %%
from ultralytics import YOLO
model = YOLO('models/ASD_Face_detecter_v2.pt')

results = model('Test_images/test1_ASD.png')  # return a list of Results objects
# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    result.show()  # display to screen
    result.tojson()
    print(result.tojson())
    result.save(filename='result.jpg')
# Out:
# image 1/1 c:\Users\kanlo\Documents\GitHub\FYP-ASD\backend\ASD_face_detecter\Test_images\test1_ASD.png: 544x640 2 ASD_FACEs, 325.4ms
# Speed: 3.0ms preprocess, 325.4ms inference, 106.2ms postprocess per image at shape (1, 3, 544, 640)
# [
#   {
#     "name": "ASD_FACE",
#     "class": 0,
#     "confidence": 0.71795,
#     "box": {
#       "x1": 78.76904,
#       "y1": 43.45353,
#       "x2": 482.0,
#       "y2": 392.09955
#     }
#   },
#   {
#     "name": "ASD_FACE",
#     "class": 0,
#     "confidence": 0.59843,
#     "box": {
#       "x1": 0.0,
#       "y1": 136.27968,
#       "x2": 394.90564,
#       "y2": 391.60623
#     }
#   }
# ]
